# %% [markdown]
# # Creating Data for the TuningTools package
#
# The TuningTools package uses numpy as the primary data source for tuning the particle selection algorithms. This documentation concerns the data transformation from a ROOT file (PhysVal) or, in a future release, directly from xAOD to the used tuning data format.
#
# Basically, there are two ways of creating the tuning data file. You can either:
# - [[Recommended] Run the shell createData.py executable](#Using-the-createData.py-executable); or
# - [Interact with the python code](#Interacting-with-the-python-code).

# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %% [markdown]
# # Retrieve data from the GRID
#
# It is most likely that you have generated the data on the GRID. The approach for running the data transformation on the GRID is currently under-development, so you will have to download and run the transformation on standalone, then upload it again to the GRID. Either way, if you want to run the tuning on standalone, this is be needed, so in order to optimize the process while implementation is not finished, you can follow the next steps.
#
# ## Optimal GRID PhysVal download
#
# The standalone approaches consider that you have already downloaded the data from the reconstructions.
#
# If you need to download the PhysVals on the GRID, you can make use of the `scripts/grid_scripts/run_dump.py` script. This simple script can be used to download the PhysVals in batches, and skimming them (thus reducing their size) to keep only the needed TTrees.
#
# An usage example of a dataset download while also removing all Trigger information can be done as follows:
#
# ```bash
# run_dump.py --inDS user.wsfreund.mc14_13TeV.129160.Pythia8_AU2CTEQ6L1_perf_JF17.e3084_s2044_s2008_r5988.rr0003.ph0002_PhysVal/ --outFolder mergedJet --triggerList '' --numberOfSamplesPerPackage 250
# ```
# It is also possible to specify the trigger list to filter using `--trigerList='e24_lhmedium_L1EM18VH' 'e24_lhtight_L1EM18VH'`...
#
# The full command options are the following:

# %%
# %%bash
# run_dump.py -- -h
# Out:
# usage: run_dump.py [-h] --inDS INDS [--outFolder OUTFOLDER] [--triggerList TRIGGERLIST [TRIGGERLIST ...]] [--numberOfSamplesPerPackage NUMBEROFSAMPLESPERPACKAGE]
# run_dump.py: error: argument --inDS is required

# %% [markdown]
# # The createData.py executable
#
# This is the preferred and supported way for creating the data files. You will need to have the xAOD/PhysVal with the rings in order to generate the data files. The command can be run after you set the environment through `source setrootcore.sh` command on the RootCore packages directory.
#
# The help information should be self-explanatory, where the most important options are `--sgnInputFiles`, `--bkgInputFiles`, `--operation`, `--reference` and `--treePath`.
#
# If you want to run a $\eta$ and $E_T$ dependent discrimination, you can specify the bins through `--etaBins` and `etBins`, respectively.

# %%
# %%bash
# createData.py
# Out:
# usage: createData.py -s SignalInputFiles [SignalInputFiles ...] -b BackgroundInputFiles [BackgroundInputFiles ...] -op OPERATION [-t TreePath [TreePath ...]]
#                      [--reference {Off_CutID,Off_Likelihood,Truth,_ignoreCase} [{Off_CutID,Off_Likelihood,Truth,_ignoreCase} ...]] [-tEff EfficienciyTreePath [EfficienciyTreePath ...]] [-l1 L1EMCLUSCUT]
#                      [-l2 L2ETCUT] [-off OFFETCUT] [--getRatesOnly] [--etBins ETBINS [ETBINS ...]] [--etaBins ETABINS [ETABINS ...]] [--ringConfig RINGCONFIG [RINGCONFIG ...]] [-nC NCLUSTERS]
#                      [-o OUTPUT] [--crossFile CROSSFILE] [--output-level {DEBUG,ERROR,FATAL,INFO,VERBOSE,WARNING,_ignoreCase}]
#
# Create TuningTool data from PhysVal.
#
# optional arguments:
#   --output-level {DEBUG,ERROR,FATAL,INFO,VERBOSE,WARNING,_ignoreCase}
#                         The output level for the main logger
#
# Required arguments:
#
#   -s SignalInputFiles [SignalInputFiles ...], --sgnInputFiles SignalInputFiles [SignalInputFiles ...]
#                         The signal files that will be used to tune the discriminators
#   -b BackgroundInputFiles [BackgroundInputFiles ...], --bkgInputFiles BackgroundInputFiles [BackgroundInputFiles ...]
#                         The background files that will be used to tune the discriminators
#   -op OPERATION, --operation OPERATION
#                         The operation environment for the algorithm
#   -t TreePath [TreePath ...], --treePath TreePath [TreePath ...]
#                         The Tree path to be filtered on the files. It can be a value for each dataset.
#
# Extra-configuration arguments:
#
#   --reference {Off_CutID,Off_Likelihood,Truth,_ignoreCase} [{Off_CutID,Off_Likelihood,Truth,_ignoreCase} ...]
#                         The reference used for filtering datasets. It needs to be set to a value on the Reference enumeration on ReadData file. You can set only one value to be used for both
#                         datasets, or one value first for the Signal dataset and the second for the Background dataset.
#   -tEff EfficienciyTreePath [EfficienciyTreePath ...], --efficiencyTreePath EfficienciyTreePath [EfficienciyTreePath ...]
#                         The Tree path to calculate efficiency. If not specified, efficiency is calculated upon treePath.
#   -l1 L1EMCLUSCUT, --l1EmClusCut L1EMCLUSCUT
#                         The L1 cut threshold
#   -l2 L2ETCUT, --l2EtCut L2ETCUT
#                         The L2 Et cut threshold
#   -off OFFETCUT, --offEtCut OFFETCUT
#                         The Offline Et cut threshold
#   --getRatesOnly        Don't save output file, just print benchmark algorithm operation reference.
#   --etBins ETBINS [ETBINS ...]
#                         E_T bins where the data should be segmented.
#   --etaBins ETABINS [ETABINS ...]
#                         eta bins where the data should be segmented.
#   --ringConfig RINGCONFIG [RINGCONFIG ...]
#                         Number of rings for each eta bin segmentation.
#   -nC NCLUSTERS, --nClusters NCLUSTERS
#                         Maximum number of events to add to each dataset.
#   -o OUTPUT, --output OUTPUT
#                         The pickle intermediate file that will be used to train the datasets.
#   --crossFile CROSSFILE
#                         Cross-Validation file which will be used to tune the Ringer Discriminators.

# %% [markdown]
# # Interacting with the python code

# %% [markdown]
# If, instead, you want to directly call the python code within a script. This is done through the `__call__` method of the `CreateData` class:

# %%
from TuningTools.CreateData import createData
help(createData.__call__)
# Out:
# Help on method __call__ in module TuningTools.CreateData:
#
# __call__(self, sgnFileList, bkgFileList, ringerOperation, **kw) method of TuningTools.CreateData.CreateData instance
#     Creates a numpy file ntuple with rings and its targets
#     Arguments:
#       - sgnFileList: A python list or a comma separated list of the root files
#           containing the TuningTool TTree for the signal dataset
#       - bkgFileList: A python list or a comma separated list of the root files
#           containing the TuningTool TTree for the background dataset
#       - ringerOperation: Set Operation type to be used by the filter
#     Optional arguments:
#       - output ['tuningData']: Name for the output file
#       - referenceSgn [Reference.Truth]: Filter reference for signal dataset
#       - referenceBkg [Reference.Truth]: Filter reference for background dataset
#       - treePath [Set using operation]: set tree name on file, this may be set to
#         use different sources then the default.
#           Default for:
#             o Offline: Offline/Egamma/Ntuple/electron
#             o L2: Trigger/HLT/Egamma/TPNtuple/e24_medium_L1EM18VH
#       - efficiencyTreePath [None]: Sets tree path for retrieving efficiency
#             benchmarks.
#           When not set, uses treePath as tree.
#       - nClusters [None]: Number of clusters to export. If set to None, export
#           full PhysVal information.
#       - getRatesOnly [False]: Do not create data, but retrieve the efficiency
#           for benchmark on the chosen operation.
#       - etBins [None]: E_T bins where the data should be segmented
#       - etaBins [None]: eta bins where the data should be segmented
#       - ringConfig [100]: A list containing the number of rings available in the data
#         for each eta bin.
#       - crossVal [None]: Whether to measure benchmark efficiency splitting it
#         by the crossVal-validation datasets

# %% [markdown]
# ## Using ReadData
#
# However, in some very special cases, you might want to run directly the `ReadData` class instead, to obtain only some of the datasets rings.
#
# Its documentation should cover all configuration:

# %%
from TuningTools.ReadData import readData
help(readData.__call__)
# Out:
# Help on method __call__ in module TuningTools.ReadData:
#
# __call__(self, fList, ringerOperation, **kw) method of TuningTools.ReadData.ReadData instance
#     Returns ntuple with rings and its targets
#     Arguments:
#       - fList: The file path or file list path. It can be an argument list of
#       two types:
#         o List: each element is a string path to the file;
#         o Comma separated string: each path is separated via a comma
#         o Folders: Expand folders recursively adding also files within them to analysis
#       - ringerOperation: Set Operation type. It can be both a string or the
#         RingerOperation
#     Optional arguments:
#       - filterType [None]: whether to filter. Use FilterType enumeration
#       - reference [Truth]: set reference for targets. Use Reference enumeration
#       - treePath [Set using operation]: set tree name on file, this may be set to
#         use different sources then the default.
#           Default for:
#             o Offline: Offline/Egamma/Ntuple/electron
#             o L2: Trigger/HLT/Egamma/TPNtuple/e24_medium_L1EM18VH
#       - efficiencyTreePath [None]: Sets tree path for retrieving efficiency
#             benchmarks.
#           When not set, uses treePath as tree.
#       - l1EmClusCut [None]: Set L1 cluster energy cut if operating on the trigger
#       - l2EtCut [None]: Set L2 cluster energy cut value if operating on the trigger
#       - offEtCut [None]: Set Offline cluster energy cut value
#       - nClusters [None]: Read up to nClusters. Use None to run for all clusters.
#       - getRatesOnly [False]: Read up to nClusters. Use None to run for all clusters.
#       - etBins [None]: E_T bins where the data should be segmented
#       - etaBins [None]: eta bins where the data should be segmented
#       - ringConfig [100]: A list containing the number of rings available in the data
#         for each eta bin.
#       - crossVal [None]: Whether to measure benchmark efficiency splitting it
#         by the crossVal-validation datasets

# %% [markdown]
# # The information available on the TuningDataArchieve
#
# We can explore the information available on the TuningDataArchieve by using the RingerCore.FileIO load method directly on the file and checking its RAW content:

# %%
from RingerCore.FileIO import load
f = load('tuningData.npz')
print f
f.keys()
# Out:
# <numpy.lib.npyio.NpzFile object at 0x53c0e90>
# ['signal_patterns_etBin_0_etaBin_2',
#  'signal_patterns_etBin_0_etaBin_3',
#  'signal_patterns_etBin_0_etaBin_0',
#  'signal_patterns_etBin_0_etaBin_1',
#  'background_patterns_etBin_2_etaBin_0',
#  'background_patterns_etBin_2_etaBin_1',
#  'background_patterns_etBin_2_etaBin_2',
#  'background_patterns_etBin_2_etaBin_3',
#  'signal_patterns_etBin_2_etaBin_0',
#  'signal_patterns_etBin_2_etaBin_1',
#  'signal_patterns_etBin_2_etaBin_2',
#  'signal_patterns_etBin_2_etaBin_3',
#  'background_efficiencies',
#  'version',
#  'signal_patterns_etBin_1_etaBin_1',
#  'signal_patterns_etBin_1_etaBin_0',
#  'signal_patterns_etBin_1_etaBin_3',
#  'signal_patterns_etBin_1_etaBin_2',
#  'type',
#  'et_bins',
#  'eta_bins',
#  'background_cross_efficiencies',
#  'background_patterns_etBin_0_etaBin_2',
#  'background_patterns_etBin_0_etaBin_3',
#  'background_patterns_etBin_0_etaBin_0',
#  'background_patterns_etBin_0_etaBin_1',
#  'background_patterns_etBin_1_etaBin_1',
#  'background_patterns_etBin_1_etaBin_0',
#  'background_patterns_etBin_1_etaBin_3',
#  'background_patterns_etBin_1_etaBin_2',
#  'signal_efficiencies',
#  'signal_cross_efficiencies']

# %% [markdown]
# In this version, we are saving each one of the `signal` and `background` rings data in a dedicated bin file, so that the rings information can be retrieved without loading the full data into memory. The other information available on the file, which are quite small in the memory, are not separated into bins. You will find, besides the rings, the `et_bins` and `eta_bins` limits, the `background` and `signal` benchmark efficiencies, which, for the trigger, will be `L2CaloAccept`, `L2ElAccept`, `EFCaloAccept` and `EFElAccept`; and, for the offline, they will be `CutIDLoose`, `CutIDMedium`, `CutIDTight`, `LHLoose`, `LHMedium` and `LHTight`. Those efficiencies are measured for all the dataset and given with respect to the used reference. However, if you provide the `CrossValid` object that will be used to tune the Ringer selector, there will be available the `background` and `signal` cross-validation datasets efficiencies to compare efficiencies in the same used datasets.
#
# One more important note: when loading only one bin into the memory, the context manager will handle and keep only the desired bin information into memory, as we can see in the following code:

# %%
from TuningTools.CreateData import TuningDataArchieve
with TuningDataArchieve("tuningData.npz", eta_bin = 0, et_bin = 0) as data: pass
print 'Background L2Calo in(et=0,eta=0) efficiency is: ', data['background_efficiencies']['L2CaloAccept'].eff_str()
print 'Background HLT bin(et=0,eta=0) efficiency is: ', data['background_efficiencies']['EFElAccept'].eff_str()
print 'Signal L2Calo bin(et=0,eta=0) efficiency is: ', data['signal_efficiencies']['L2CaloAccept'].eff_str()
print 'Signal HLT bin(et=0,eta=0) efficiency is: ', data['signal_efficiencies']['EFElAccept'].eff_str()
data
# Out:
# Background L2Calo in(et=0,eta=0) efficiency is:  1.398601 (6/429)
# Background HLT bin(et=0,eta=0) efficiency is:  0.233100 (1/429)
# Signal L2Calo bin(et=0,eta=0) efficiency is:  72.950820 (89/122)
# Signal HLT bin(et=0,eta=0) efficiency is:  60.655738 (74/122)
# {'background_cross_efficiencies': OrderedDict([('L2CaloAccept',
#                <TuningTools.ReadData.BranchCrossEffCollector at 0x27af390>),
#               ('L2ElAccept',
#                <TuningTools.ReadData.BranchCrossEffCollector at 0x5b6df90>),
#               ('EFCaloAccept',
#                <TuningTools.ReadData.BranchCrossEffCollector at 0x647c350>),
#               ('EFElAccept',
#                <TuningTools.ReadData.BranchCrossEffCollector at 0x5b73d10>)]),
#  'background_efficiencies': OrderedDict([('L2CaloAccept',
#                <TuningTools.ReadData.BranchEffCollector at 0x53c5710>),
#               ('L2ElAccept',
#                <TuningTools.ReadData.BranchEffCollector at 0x53c5650>),
#               ('EFCaloAccept',
#                <TuningTools.ReadData.BranchEffCollector at 0x53c5390>),
#               ('EFElAccept',
#                <TuningTools.ReadData.BranchEffCollector at 0x53c5750>)]),
#  'background_patterns': array([[  192.13546753,  1005.24487305,     2.97116709, ...,
#            -42.61797333,   -30.61290741,    -1.20050848],
#         [  105.07989502,   558.48016357,  -149.83615112, ...,
#             81.99632263,  -125.96536255,   140.22558594],
#         [  102.99015808,   241.97686768,   113.98910522, ...,
#             41.82086182,    46.06355667,   -71.51972961],
#         ...,
#         [  307.11074829,   499.38122559,   880.44213867, ...,
#            -62.37562561,  -130.57977295,  1139.6105957 ],
#         [  514.49755859,   229.41215515,   845.65734863, ...,
#             94.58357239,   153.33644104,   -10.02835178],
#         [  365.66726685,   297.27563477,  -142.2545929 , ...,
#             69.52016449,   -68.39887238,    21.30456924]], dtype=float32),
#  'et_bins': array([  0.,  30.], dtype=float32),
#  'eta_bins': array([ 0.        ,  0.80000001], dtype=float32),
#  'signal_cross_efficiencies': OrderedDict([('L2CaloAccept',
#                <TuningTools.ReadData.BranchCrossEffCollector at 0x2946910>),
#               ('L2ElAccept',
#                <TuningTools.ReadData.BranchCrossEffCollector at 0x53c0e50>),
#               ('EFCaloAccept',
#                <TuningTools.ReadData.BranchCrossEffCollector at 0x5b89bd0>),
#               ('EFElAccept',
#                <TuningTools.ReadData.BranchCrossEffCollector at 0x5b8c610>)]),
#  'signal_efficiencies': OrderedDict([('L2CaloAccept',
#                <TuningTools.ReadData.BranchEffCollector at 0x63f4150>),
#               ('L2ElAccept',
#                <TuningTools.ReadData.BranchEffCollector at 0x53c5810>),
#               ('EFCaloAccept',
#                <TuningTools.ReadData.BranchEffCollector at 0x53c5790>),
#               ('EFElAccept',
#                <TuningTools.ReadData.BranchEffCollector at 0x53c5890>)]),
#  'signal_patterns': array([[  5.15951050e+02,   9.19912643e+01,   9.99905050e-01, ...,
#           -1.87890816e+01,  -3.45476723e+01,   6.06101990e-01],
#         [  3.61108582e+02,   9.21477539e+02,   1.97633759e+02, ...,
#           -2.85347157e+01,  -3.81873230e+02,  -1.47667526e+02],
#         [  1.35985486e+03,   6.79078598e+01,   3.06434235e+02, ...,
#           -2.24961262e+01,   1.32011353e+02,   6.92042875e+00],
#         ...,
#         [  1.27294214e+03,   8.21906555e+02,   3.00396729e+02, ...,
#            4.01561089e+01,  -1.60624447e+01,  -3.93707752e+00],
#         [  4.58647980e+02,   1.34280960e+02,   1.25561424e+02, ...,
#           -1.26786451e+01,  -3.69793820e+00,   6.33932266e+01],
#         [  4.24220337e+02,  -1.14789032e+02,  -7.28660812e+01, ...,
#            7.08072510e+01,  -3.44958382e+01,  -1.14986191e+01]], dtype=float32)}

# %% [markdown]
# We can also do not request to load a specific bin, but rather the full data available for all bins in the file:

# %%
from TuningTools.CreateData import TuningDataArchieve
with TuningDataArchieve("tuningData.npz") as data: pass
print 'Background L2Calo in(et=1,eta=0) efficiency is: ', data['background_efficiencies']['L2CaloAccept'][1][0].eff_str()
print 'Background HLT bin(et=1,eta=0) efficiency is: ', data['background_efficiencies']['EFElAccept'][1][0].eff_str()
print 'Signal L2Calo bin(et=1,eta=0) efficiency is: ', data['signal_efficiencies']['L2CaloAccept'][1][0].eff_str()
print 'Signal HLT bin(et=1,eta=0) efficiency is: ', data['signal_efficiencies']['EFElAccept'][1][0].eff_str()
data
# Out:
# Background L2Calo in(et=1,eta=0) efficiency is:  1.265823 (2/158)
# Background HLT bin(et=1,eta=0) efficiency is:  0.000000 (0/158)
# Signal L2Calo bin(et=1,eta=0) efficiency is:  99.180328 (484/488)
# Signal HLT bin(et=1,eta=0) efficiency is:  96.926230 (473/488)
# {'background_cross_efficiencies': OrderedDict([('L2CaloAccept',
#                [[<TuningTools.ReadData.BranchCrossEffCollector at 0x5dee1d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5defbd0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6614590>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6616f10>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x6618950>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x661a350>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x661bcd0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x661d710>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x661f0d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6620ad0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6622490>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6623e90>]]),
#               ('L2ElAccept',
#                [[<TuningTools.ReadData.BranchCrossEffCollector at 0x6625890>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6627290>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6628c10>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x662a650>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x662bfd0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x662d9d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x662f3d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6630dd0>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x6093790>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60951d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6096b50>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6098590>]]),
#               ('EFCaloAccept',
#                [[<TuningTools.ReadData.BranchCrossEffCollector at 0x6099f10>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x609b910>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x609d310>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x609ed10>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x60a0710>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60a20d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60a3a90>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60a54d0>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x60a6e50>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60a8850>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60aa290>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60abc10>]]),
#               ('EFElAccept',
#                [[<TuningTools.ReadData.BranchCrossEffCollector at 0x60ad650>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60aefd0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60b0a10>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60b2410>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x60b3d90>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60b57d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60b7190>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60b8b50>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x60ba590>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60bbf10>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60bd910>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x60bf310>]])]),
#  'background_efficiencies': OrderedDict([('L2CaloAccept',
#                [[<TuningTools.ReadData.BranchEffCollector at 0x63e6350>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6310>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6450>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6490>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x63e64d0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6390>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e63d0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6410>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x63e6510>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6550>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6590>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e65d0>]]),
#               ('L2ElAccept',
#                [[<TuningTools.ReadData.BranchEffCollector at 0x63e6610>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6650>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6690>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e66d0>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x63e6710>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6750>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6790>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e67d0>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x63e6810>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6850>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6890>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e68d0>]]),
#               ('EFCaloAccept',
#                [[<TuningTools.ReadData.BranchEffCollector at 0x63e6910>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6950>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6990>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e69d0>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x63e6a10>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6a50>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6a90>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6ad0>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x63e6b10>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6b50>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6b90>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6bd0>]]),
#               ('EFElAccept',
#                [[<TuningTools.ReadData.BranchEffCollector at 0x63e6c10>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6c50>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6c90>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6cd0>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x63e6d10>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6d50>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6d90>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6dd0>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x63e6e10>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6e50>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6e90>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e
     0.        ],
#           [    0.        ,     0.        ,     0.        , ...,
#             1032.40283203,   388.87927246,     0.        ],
#           [    0.        ,     0.        ,     0.        , ...,
#              699.88928223,   177.18714905,     0.        ],
#           ...,
#           [    0.        ,     0.        ,     0.        , ...,
#             2052.73974609,  -612.10150146,     0.        ],
#           [    0.        ,     0.        ,     0.        , ...,
#              522.13574219,   289.45217896,     0.        ],
#           [    0.        ,     0.        ,     0.        , ...,
#              553.60217285,  -259.57943726,     0.        ]], dtype=float32)]],
#  'et_bins': array([     0.,     30.,     50.,  20000.], dtype=float32),
#  'eta_bins': array([ 0.        ,  0.80000001,  1.37      ,  1.53999996,  2.5       ], dtype=float32),
#  'signal_cross_efficiencies': OrderedDict([('L2CaloAccept',
#                [[<TuningTools.ReadData.BranchCrossEffCollector at 0x63e6f90>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x53c0cd0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x64489d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x644d3d0>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x644fd90>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x64517d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6454190>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6455b90>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x645f590>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6463f50>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x6472950>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x647b310>]]),
#               ('L2ElAccept',
#                [[<TuningTools.ReadData.BranchCrossEffCollector at 0x5dc6cd0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dc26d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5db3110>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5db4a90>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x5dbb490>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dbee50>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5db1850>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5db5250>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x5db8c10>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dbc650>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dbffd0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dc3a10>]]),
#               ('EFCaloAccept',
#                [[<TuningTools.ReadData.BranchCrossEffCollector at 0x5dc7410>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dc8dd0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dca7d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dcc190>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x5dcdb50>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dcf550>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dd0f50>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dd2910>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x5dd4310>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dd5d10>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dd76d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dd9110>]]),
#               ('EFElAccept',
#                [[<TuningTools.ReadData.BranchCrossEffCollector at 0x5ddaa90>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5ddc4d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5ddde50>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5ddf850>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x5de1250>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5de2c10>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5de4610>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5de5fd0>],
#                 [<TuningTools.ReadData.BranchCrossEffCollector at 0x5de79d0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5de9410>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5deadd0>,
#                  <TuningTools.ReadData.BranchCrossEffCollector at 0x5dec790>]])]),
#  'signal_efficiencies': OrderedDict([('L2CaloAccept',
#                [[<TuningTools.ReadData.BranchEffCollector at 0x5b91790>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b913d0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91850>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91710>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x5b91750>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91890>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91810>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91950>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x5b916d0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91910>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b917d0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91990>]]),
#               ('L2ElAccept',
#                [[<TuningTools.ReadData.BranchEffCollector at 0x5b919d0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91a10>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91a50>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91a90>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x5b91ad0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91b10>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91b50>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91b90>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x5b91bd0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91c10>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91c50>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91c90>]]),
#               ('EFCaloAccept',
#                [[<TuningTools.ReadData.BranchEffCollector at 0x5b91cd0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91d10>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91d50>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91d90>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x5b91dd0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91e10>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91e50>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91e90>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x5b91ed0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91f10>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91f50>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x5b91f90>]]),
#               ('EFElAccept',
#                [[<TuningTools.ReadData.BranchEffCollector at 0x5b91fd0>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6050>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6090>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e60d0>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x63e6110>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6150>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6190>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e61d0>],
#                 [<TuningTools.ReadData.BranchEffCollector at 0x63e6210>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63e6250>,
#                  <TuningTools.ReadData.BranchEffCollector at 0x63
#             -4.45002708e+01,   5.46692734e+01,   4.25012390e+02],
#           ...,
#           [  3.15200781e+03,   3.41467505e+03,   5.02856995e+02, ...,
#             -3.59511841e+02,  -4.02847229e+02,   2.39658911e+03],
#           [  7.76450244e+03,   2.28757959e+03,   5.77423401e+02, ...,
#              1.77841394e+03,   8.21453857e+02,   6.97656403e+01],
#           [  3.00621045e+03,   2.73129932e+03,  -2.28004120e+02, ...,
#             -6.59722900e+02,   5.59601257e+02,   4.39538300e+02]], dtype=float32),
#    array([[  3.20581055e+03,   2.65991577e+03,   3.53951050e+02, ...,
#              2.70162476e+03,  -1.60243335e+03,  -1.21174995e+02],
#           [  4.33945459e+03,   5.04264307e+03,   8.23995850e+02, ...,
#              4.73802368e+02,   2.00404041e+03,   2.73409912e+02],
#           [  1.80602617e+04,   1.11975859e+04,   8.75045959e+02, ...,
#              1.27898975e+04,   1.56628064e+03,   9.17647705e+02],
#           ...,
#           [  9.12737988e+03,   6.17278760e+03,   5.67982959e+03, ...,
#              6.64896289e+03,   6.17808960e+02,  -1.10420637e+01],
#           [  7.01214990e+03,   4.23219922e+03,   1.39961011e+03, ...,
#              2.10710449e+03,   6.05216614e+02,   1.09506790e+02],
#           [  1.27216777e+04,   2.79483765e+03,   8.01405212e+02, ...,
#              2.45670703e+03,   9.16926575e+02,   4.32272003e+02]], dtype=float32),
#    array([[    0.        ,     0.        ,     0.        , ...,
#             -486.36578369,  -116.26438141,     0.        ],
#           [    0.        ,     0.        ,     0.        , ...,
#             -273.06900024,   262.94146729,     0.        ],
#           [ 1960.64685059,   272.08303833,    36.27773666, ...,
#             -607.24182129,   601.61187744,   440.19049072],
#           ...,
#           [ 4782.71972656,  2638.62963867,   305.83377075, ...,
#             3212.0090332 ,   457.74313354,    14.73654556],
#           [ 2243.28344727,   188.64424133,   -12.86210728, ...,
#             -873.75201416,  -180.26948547,   364.59777832],
#           [  593.3059082 ,   307.04159546,    87.39636993, ...,
#            -1111.85668945,  -489.44400024,  -467.58505249]], dtype=float32)]]}

# %% [markdown]
# Please note that loading all information is not needed, generally, as the bin information is treated separately for each tuning.

# %% [markdown]
# # Examples

# %% [markdown]
# ## Example 1: Creating data using the command line

# %% [markdown]
# The following example retrieves data from two folders filled with files of two full runs of simulated data specified as signal (`-s`) and background (`-b`).
#
# The algorithm is specified to operate in the fast calorimeter step (`-op L2`) and the references used to filter the targets are the offline likelihood and the truth for, respectively, the signal and background datasets.
#
# It is specified a cut of 19 GeV on L2 cluster measured energy, so the algorithm will be trained only with candidates that pass this threshold. This cut should be the threshold applied on the chain to avoid passing candidates with lower energy that the selector will receive during its operation. A energy cut of 20 GeV is required on L1EMCluster, to operate closer of a L1EM20VH.
#
# The trigger chains are specified for the signal and background datasets afterwards through the `-t` flag.
#
# A cross validation file is passed for also measuring the baseline efficiency on the datasets that will be used for training. If this is not specified, the baseline efficiencies will be measured only for the full dataset.
#
# A maximum number of clusters is specified (1000), as this is just an example.
#
# The $E_T$ and $|\eta|$ bins are specified through the `--etBins` and `--etaBins` flags.

# %%
# %%bash
# createData.py \
#   -s /afs/cern.ch/work/j/jodafons/public/Online/PhysVal/user.jodafons.mc14_13TeV.147406.PowhegPythia8_AZNLO_Zee.recon.RDO.rel20.1.0.4.e3059_s1982_s2008_r5993_rr0104_a0001_PhysVal.root  \
#   -b /afs/cern.ch/work/j/jodafons/public/Online/PhysVal/user.jodafons.mc14_13TeV.129160.Pythia8_AU2CTEQ6L1_perf_JF17.recon.RDO.rel20.1.0.4.e3084_s2044_s2008_r5988.rr0104_a0001_PhysVal.root \
#   -op L2 \
#   --reference Off_Likelihood Truth \
#   -l1 20 \
#   -l2 19 \
#   -t Trigger/HLT/Egamma/ZeeNtuple/e24_lhmedium_ringer_L1EM18VH \
#      Trigger/HLT/Egamma/BackgroundNtuple/e24_lhmedium_ringer_L1EM18VH \
#   --crossFile /afs/cern.ch/work/w/wsfreund/private/crossValid.pic.gz \
#   --nClusters 10000 \
#   --etBins 0 30  50  20000 \
#   --etaBins 0  0.8   1.37  1.54  2.5
#   #--output-level VERBOSE
# Out:
# Py.CreateData                           INFO Extracting signal dataset information...
# Py.ReadData                         INFO There is available a total of 306345 entries.
# Py.ReadData                         INFO L2CaloAccept_etBin0_etaBin0 : 78.623719 (537/683)
# Py.ReadData                         INFO L2ElAccept_etBin0_etaBin0 : 0.000000 (0/683)
# Py.ReadData                         INFO EFCaloAccept_etBin0_etaBin0 : 78.623719 (537/683)
# Py.ReadData                         INFO EFElAccept_etBin0_etaBin0 : 60.907760 (416/683)
# Py.ReadData                         INFO L2CaloAccept_etBin0_etaBin1 : 80.940594 (327/404)
# Py.ReadData                         INFO L2ElAccept_etBin0_etaBin1 : 0.000000 (0/404)
# Py.ReadData                         INFO EFCaloAccept_etBin0_etaBin1 : 80.940594 (327/404)
# Py.ReadData                         INFO EFElAccept_etBin0_etaBin1 : 66.336634 (268/404)
# Py.ReadData                         INFO L2CaloAccept_etBin0_etaBin2 : 80.000000 (60/75)
# Py.ReadData                         INFO L2ElAccept_etBin0_etaBin2 : 0.000000 (0/75)
# Py.ReadData                         INFO EFCaloAccept_etBin0_etaBin2 : 80.000000 (60/75)
# Py.ReadData                         INFO EFElAccept_etBin0_etaBin2 : 68.000000 (51/75)
# Py.ReadData                         INFO L2CaloAccept_etBin0_etaBin3 : 79.432624 (448/564)
# Py.ReadData                         INFO L2ElAccept_etBin0_etaBin3 : 0.000000 (0/564)
# Py.ReadData                         INFO EFCaloAccept_etBin0_etaBin3 : 79.432624 (448/564)
# Py.ReadData                         INFO EFElAccept_etBin0_etaBin3 : 61.524823 (347/564)
# Py.ReadData                         INFO L2CaloAccept_etBin1_etaBin0 : 98.890259 (2406/2433)
# Py.ReadData                         INFO L2ElAccept_etBin1_etaBin0 : 0.000000 (0/2433)
# Py.ReadData                         INFO EFCaloAccept_etBin1_etaBin0 : 98.890259 (2406/2433)
# Py.ReadData                         INFO EFElAccept_etBin1_etaBin0 : 96.752980 (2354/2433)
# Py.ReadData                         INFO L2CaloAccept_etBin1_etaBin1 : 98.639015 (1522/1543)
# Py.ReadData                         INFO L2ElAccept_etBin1_etaBin1 : 0.000000 (0/1543)
# Py.ReadData                         INFO EFCaloAccept_etBin1_etaBin1 : 98.639015 (1522/1543)
# Py.ReadData                         INFO EFElAccept_etBin1_etaBin1 : 96.241089 (1485/1543)
# Py.ReadData                         INFO L2CaloAccept_etBin1_etaBin2 : 92.757660 (333/359)
# Py.ReadData                         INFO L2ElAccept_etBin1_etaBin2 : 0.000000 (0/359)
# Py.ReadData                         INFO EFCaloAccept_etBin1_etaBin2 : 92.757660 (333/359)
# Py.ReadData                         INFO EFElAccept_etBin1_etaBin2 : 86.350975 (310/359)
# Py.ReadData                         INFO L2CaloAccept_etBin1_etaBin3 : 96.650068 (2135/2209)
# Py.ReadData                         INFO L2ElAccept_etBin1_etaBin3 : 0.000000 (0/2209)
# Py.ReadData                         INFO EFCaloAccept_etBin1_etaBin3 : 96.650068 (2135/2209)
# Py.ReadData                         INFO EFElAccept_etBin1_etaBin3 : 87.958352 (1943/2209)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin0 : 99.041534 (620/626)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin0 : 0.000000 (0/626)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin0 : 99.041534 (620/626)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin0 : 97.284345 (609/626)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin1 : 99.769585 (433/434)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin1 : 0.000000 (0/434)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin1 : 99.769585 (433/434)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin1 : 97.695853 (424/434)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin2 : 90.410959 (66/73)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin2 : 0.000000 (0/73)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin2 : 90.410959 (66/73)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin2 : 83.561644 (61/73)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin3 : 97.152429 (580/597)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin3 : 0.000000 (0/597)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin3 : 97.152429 (580/597)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin3 : 90.117253 (538/597)
# Py.CreateData                           INFO Extracted Signal rings (et=0,eta=0) with size: (683, 100)
# Py.CreateData                           INFO Extracted Signal rings (et=0,eta=1) with size: (404, 100)
# Py.CreateData                           INFO Extracted Signal rings (et=0,eta=2) with size: (75, 100)
# Py.CreateData                           INFO Extracted Signal rings (et=0,eta=3) with size: (564, 100)
# Py.CreateData                           INFO Extracted Signal rings (et=1,eta=0) with size: (2433, 100)
# Py.CreateData                           INFO Extracted Signal rings (et=1,eta=1) with size: (1543, 100)
# Py.CreateData                           INFO Extracted Signal rings (et=1,eta=2) with size: (359, 100)
# Py.CreateData                           INFO Extracted Signal rings (et=1,eta=3) with size: (2209, 100)
# Py.CreateData                           INFO Extracted Signal rings (et=2,eta=0) with size: (626, 100)
# Py.CreateData                           INFO Extracted Signal rings (et=2,eta=1) with size: (434, 100)
# Py.CreateData                           INFO Extracted Signal rings (et=2,eta=2) with size: (73, 100)
# Py.CreateData                           INFO Extracted Signal rings (et=2,eta=3) with size: (597, 100)
# Py.CreateData                           INFO Extracting background dataset information...
# Py.ReadData                         INFO There is available a total of 16246 entries.
# Py.ReadData                         INFO L2CaloAccept_etBin0_etaBin0 : 1.257334 (30/2386)
# Py.ReadData                         INFO L2ElAccept_etBin0_etaBin0 : 0.000000 (0/2386)
# Py.ReadData                         INFO EFCaloAccept_etBin0_etaBin0 : 1.257334 (30/2386)
# Py.ReadData                         INFO EFElAccept_etBin0_etaBin0 : 0.209556 (5/2386)
# Py.ReadData                         INFO L2CaloAccept_etBin0_etaBin1 : 2.125454 (41/1929)
# Py.ReadData                         INFO L2ElAccept_etBin0_etaBin1 : 0.000000 (0/1929)
# Py.ReadData                         INFO EFCaloAccept_etBin0_etaBin1 : 2.073613 (40/1929)
# Py.ReadData                         INFO EFElAccept_etBin0_etaBin1 : 0.207361 (4/1929)
# Py.ReadData                         INFO L2CaloAccept_etBin0_etaBin2 : 4.605263 (7/152)
# Py.ReadData                         INFO L2ElAccept_etBin0_etaBin2 : 0.000000 (0/152)
# Py.ReadData                         INFO EFCaloAccept_etBin0_etaBin2 : 4.605263 (7/152)
# Py.ReadData                         INFO EFElAccept_etBin0_etaBin2 : 0.000000 (0/152)
# Py.ReadData                         INFO L2CaloAccept_etBin0_etaBin3 : 4.897219 (81/1654)
# Py.ReadData                         INFO L2ElAccept_etBin0_etaBin3 : 0.000000 (0/1654)
# Py.ReadData                         INFO EFCaloAccept_etBin0_etaBin3 : 4.897219 (81/1654)
# Py.ReadData                         INFO EFElAccept_etBin0_etaBin3 : 0.302297 (5/1654)
# Py.ReadData                         INFO L2CaloAccept_etBin1_etaBin0 : 3.551609 (32/901)
# Py.ReadData                         INFO L2ElAccept_etBin1_etaBin0 : 0.000000 (0/901)
# Py.ReadData                         INFO EFCaloAccept_etBin1_etaBin0 : 3.551609 (32/901)
# Py.ReadData                         INFO EFElAccept_etBin1_etaBin0 : 0.000000 (0/901)
# Py.ReadData                         INFO L2CaloAccept_etBin1_etaBin1 : 5.350773 (45/841)
# Py.ReadData                         INFO L2ElAccept_etBin1_etaBin1 : 0.000000 (0/841)
# Py.ReadData                         INFO EFCaloAccept_etBin1_etaBin1 : 5.350773 (45/841)
# Py.ReadData                         INFO EFElAccept_etBin1_etaBin1 : 0.594530 (5/841)
# Py.ReadData                         INFO L2CaloAccept_etBin1_etaBin2 : 11.971831 (17/142)
# Py.ReadData                         INFO L2ElAccept_etBin1_etaBin2 : 0.000000 (0/142)
# Py.ReadData                         INFO EFCaloAccept_etBin1_etaBin2 : 11.971831 (17/142)
# Py.ReadData                         INFO EFElAccept_etBin1_etaBin2 : 1.408451 (2/142)
# Py.ReadData                         INFO L2CaloAccept_etBin1_etaBin3 : 10.435931 (79/757)
# Py.ReadData                         INFO L2ElAccept_etBin1_etaBin3 : 0.000000 (0/757)
# Py.ReadData                         INFO EFCaloAccept_etBin1_etaBin3 : 10.435931 (79/757)
# Py.ReadData                         INFO EFElAccept_etBin1_etaBin3 : 1.585205 (12/757)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin0 : 2.208835 (11/498)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin0 : 0.000000 (0/498)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin0 : 2.208835 (11/498)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin0 : 0.200803 (1/498)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin1 : 5.128205 (16/312)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin1 : 0.000000 (0/312)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin1 : 5.128205 (16/312)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin1 : 0.961538 (3/312)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin2 : 0.000000 (0/50)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin2 : 0.000000 (0/50)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin2 : 0.000000 (0/50)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin2 : 0.000000 (0/50)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin3 : 4.761905 (18/378)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin3 : 0.000000 (0/378)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin3 : 4.761905 (18/378)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin3 : 0.529101 (2/378)
# Py.CreateData                           INFO Extracted Background rings (et=0,eta=0) with size: (2386, 100)
# Py.CreateData                           INFO Extracted Background rings (et=0,eta=1) with size: (1929, 100)
# Py.CreateData                           INFO Extracted Background rings (et=0,eta=2) with size: (152, 100)
# Py.CreateData                           INFO Extracted Background rings (et=0,eta=3) with size: (1654, 100)
# Py.CreateData                           INFO Extracted Background rings (et=1,eta=0) with size: (901, 100)
# Py.CreateData                           INFO Extracted Background rings (et=1,eta=1) with size: (841, 100)
# Py.CreateData                           INFO Extracted Background rings (et=1,eta=2) with size: (142, 100)
# Py.CreateData                           INFO Extracted Background rings (et=1,eta=3) with size: (757, 100)
# Py.CreateData                           INFO Extracted Background rings (et=2,eta=0) with size: (498, 100)
# Py.CreateData                           INFO Extracted Background rings (et=2,eta=1) with size: (312, 100)
# Py.CreateData                           INFO Extracted Background rings (et=2,eta=2) with size: (50, 100)
# Py.CreateData                           INFO Extracted Background rings (et=2,eta=3) with size: (378, 100)
# Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
# Py.CreateData                           INFO Saved data file at path: tuningtoolData
# Py.CreateData                           INFO Efficiency for L2CaloAccept_etBin0_etaBin0: Det(%): 78.623719 (537/683) | FA(%): 1.257334 (30/2386)
# Py.CreateData                           INFO Train_L2CaloAccept_etBin0_etaBin0: Det(%): 76.561277 +- 0.042984 (count: 313.5800/409.5800 +- 0.7507/0.7507) | FA(%): 1.187450 +- 0.000718 (count: 17.0000/1431.6400 +- 0.0000/0.8663)
# Py.CreateData                           INFO Validation_L2CaloAccept_etB
9600 +- 0.0000/0.6312)
# Py.CreateData                           INFO Efficiency for EFElAccept_etBin2_etaBin2: Det(%): 83.561644 (61/73) | FA(%): 0.000000 (0/50)
# Py.CreateData                           INFO Train_EFElAccept_etBin2_etaBin2: Det(%): 81.637478 +- 0.318061 (count: 35.5800/43.5800 +- 0.7507/0.7507) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/30.0000 +- 0.0000/0.0000)
# Py.CreateData                           INFO Validation_EFElAccept_etBin2_etaBin2: Det(%): 86.395000 +- 0.345330 (count: 25.4200/29.4200 +- 0.7507/0.7507) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/20.0000 +- 0.0000/0.0000)
# Py.CreateData                           INFO Efficiency for EFElAccept_etBin2_etaBin3: Det(%): 90.117253 (538/597) | FA(%): 0.529101 (2/378)
# Py.CreateData                           INFO Train_EFElAccept_etBin2_etaBin3: Det(%): 90.231600 +- 0.021965 (count: 323.3000/358.3000 +- 0.8062/0.8062) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/226.8400 +- 0.0000/0.7031)
# Py.CreateData                           INFO Validation_EFElAccept_etBin2_etaBin3: Det(%): 89.945424 +- 0.033998 (count: 214.7000/238.7000 +- 0.8062/0.8062) | FA(%): 1.323130 +- 0.006162 (count: 2.0000/151.1600 +- 0.0000/0.7031)

# %% [markdown]
# Note that a file mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_nod0_L1EM20VH.npz was created, containing the tuning data to be used by the `TuningJob.py`. This file also contains the efficiencies benchmarks, as we will check on the information available on the [`TuningDataArchieve`](#The-information-available-on-the-TuningDataArchieve).

# %%
# %%bash
# ls
# Out:
# CreateData.ipynb
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_nod0_L1EM18VH.npz
# Tuning.ipynb

# %% [markdown]
# ## Example 2: Creating data using a python script

# %% [markdown]
# The same example as above, but using python script:

# %%
# %load ../scripts/skeletons/create_data.py
#!/usr/bin/env python
from TuningTools.ReadData import *
from TuningTools.CreateData import createData
from RingerCore.Logger import LoggingLevel

from TuningTools.CrossValid import CrossValidArchieve
with CrossValidArchieve( "/afs/cern.ch/work/w/wsfreund/private/crossValid.pic.gz" ) as CVArchieve:
  crossVal = CVArchieve
del CVArchieve

RatesOnly=False
etaBins  = [0, 0.8 , 1.37, 1.54, 2.5]
etBins   = [0, 30, 50, 20000] # in GeV
output   = 'mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_nod0_L1EM18VH'
basepath = '/afs/cern.ch/work/j/jodafons/public/Online/PhysVal/'
bkgName  = 'user.jodafons.mc14_13TeV.129160.Pythia8_AU2CTEQ6L1_perf_JF17.recon.RDO.rel20.1.0.4.e3084_s2044_s2008_r5988.rr0104_a0001_PhysVal.root'
sgnName  = 'user.jodafons.mc14_13TeV.147406.PowhegPythia8_AZNLO_Zee.recon.RDO.rel20.1.0.4.e3059_s1982_s2008_r5993_rr0104_a0001_PhysVal.root'
treePathList = ['Trigger/HLT/Egamma/ZeeNtuple/e24_lhmedium_ringer_L1EM18VH', \
                'Trigger/HLT/Egamma/BackgroundNtuple/e24_lhmedium_ringer_L1EM18VH']

createData( basepath + '/' + sgnName, 
            basepath + '/' + bkgName,
            RingerOperation.L2,
            referenceSgn       = Reference.Off_Likelihood,
            referenceBkg       = Reference.Truth,
            treePath           = treePathList,
            l1EmClusCut        = 0,
            l2EtCut            = 19,
            # level              = LoggingLevel.DEBUG,
            nClusters          = 2000,
            getRatesOnly       = RatesOnly,
            etBins             = etBins,
            etaBins            = etaBins,
            crossVal           = crossVal )
# Out:
# Py.CreateData                           INFO Extracting signal dataset information...
# Py.ReadData                         INFO There is available a total of 306345 entries.
# Py.ReadData                         INFO L2CaloAccept_etBin0_etaBin0 : 72.950820 (89/122)
# Py.ReadData                         INFO L2ElAccept_etBin0_etaB

# Py.ReadData                         INFO EFElAccept_etBin1_etaBin3 : 1.986755 (3/151)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin0 : 3.703704 (3/81)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin0 : 0.000000 (0/81)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin0 : 3.703704 (3/81)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin0 : 0.000000 (0/81)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin1 : 5.454545 (3/55)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin1 : 0.000000 (0/55)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin1 : 5.454545 (3/55)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin1 : 1.818182 (1/55)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin2 : 0.000000 (0/7)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin2 : 0.000000 (0/7)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin2 : 0.000000 (0/7)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin2 : 0.000000 (0/7)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin3 : 3.846154 (3/78)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin3 : 0.000000 (0/78)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin3 : 3.846154 (3/78)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin3 : 0.000000 (0/78)
# Py.CreateData                           INFO Extracted Background rings (et=0,eta=0) with size: (429, 100)
# Py.CreateData                           INFO Extracted Background rings (et=0,eta=1) with size: (458, 100)
# Py.CreateData                           INFO Extracted Background rings (et=0,eta=2) with size: (40, 100)
# Py.CreateData                           INFO Extracted Background rings (et=0,eta=3) with size: (345, 100)
# Py.CreateData                           INFO Extracted Background rings (et=1,eta=0) with size: (158, 100)
# Py.CreateData                           INFO Extracted Background rings (et=1,eta=1) with size: (172, 100)
# Py.CreateData                           INFO Extracted Background rings (et=1,eta=2) with size: (26, 100)
# Py.CreateData                           INFO Extracted Background rings (et=1,eta=3) with size: (151, 100)
# Py.CreateData                           INFO Extracted Background rings (et=2,eta=0) with size: (81, 100)
# Py.CreateData                           INFO Extracted Background rings (et=2,eta=1) with size: (55, 100)
# Py.CreateData                           INFO Extracted Background rings (et=2,eta=2) with size: (7, 100)
# Py.CreateData                           INFO Extracted Background rings (et=2,eta=3) with size: (78, 100)
# Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
# Py.CreateData                           INFO Saved data file at path: tuningData
# Py.CreateData                           INFO Efficiency for L2CaloAccept_etBin0_etaBin0: Det(%): 72.950820 (89/122) | FA(%): 1.398601 (6/429)
# Py.CreateData                           INFO Train_L2CaloAccept_etBin0_etaBin0: Det(%): 67.138837 +- 0.284101 (count: 49.0400/73.0400 +- 0.6312/0.6312) | FA(%): 1.553766 +- 0.002995 (count: 4.0000/257.4400 +- 0.0000/0.4964)
# Py.CreateData                           INFO Validation_L2CaloAccept_etBin0_etaBin0: Det(%): 81.614592 +- 0.237016 (count: 39.9600/48.9600 +- 0.6312/0.6312) | FA(%): 1.165783 +- 0.003375 (count: 2.0000/171.5600 +- 0.0000/0.4964)
# Py.CreateData                           INFO Efficiency for L2CaloAccept_etBin0_etaBin1: Det(%): 81.250000 (65/80) | FA(%): 1.965066 (9/458)
# Py.CreateData                           INFO Train_L2CaloAccept_etBin0_etaBin1: Det(%): 79.166667 +- 0.000000 (count: 38.0000/48.0000 +- 0.0000/0.0000) | FA(%): 2.183103 +- 0.005582 (count: 6.0000/274.8400 +- 0.0000/0.7031)
# Py.CreateData                           INFO Validation_L2CaloAccept_etBin0_etaBin1: Det(%): 84.375000 +- 0.000000 (count: 27.0000/32.0000 +- 0.0000/0.0000) | FA(%): 1.637936 +- 0.006294 (count: 3.0000/183.1600 +- 0.0000/0.7031)
# Py.CreateData                           INFO Efficiency for L2CaloAccept_etBin0_etaBin2: Det(%): 86.363636 (19/22) | FA(%): 2.500000 (1/40)
# Py.CreateData                           INFO Train_L2CaloAccept_etBin0_etaBin2: Det(%): 84.626374 +- 0.749270 (count: 11.0400/13.0400 +- 0.6312/0.6312) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/24.0000 +- 0.0000/0.0000)
# Py.CreateData                           INFO Validation_L2CaloAccept_etBin0_etaBin2: Det(%): 88.783333 +- 0.797159 (count: 7.9600/8.9600 +- 0.6312/0.6312) | FA(%): 6.250000 +- 0.000000 (count: 1.0000/16.0000 +- 0.0000/0.0000)
# Py.CreateData                           INFO Efficiency for L2CaloAccept_etBin0_etaBin3: Det(%): 78.571429 (99/126) | FA(%): 4.347826 (15/345)
# Py.CreateData                           INFO Train_L2CaloAccept_etBin0_etaBin3: Det(%): 78.844396 +- 0.242268 (count: 59.6400/75.6400 +- 0.8663/0.8663) | FA(%): 4.832866 +- 0.019735 (count: 10.0000/206.9200 +- 0.0000/0.8447)
# Py.CreateData                           INFO Validation_L2CaloAccept_etB

# Py.CreateData                           INFO Train_L2CaloAccept_etBin2_etaBin2: Det(%): 92.313187 +- 0.374635 (count: 12.0400/13.0400 +- 0.6312/0.6312) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/4.3000 +- 0.0000/0.8062)
# Py.CreateData                           INFO Validation_L2CaloAccept_etBin2_etaBin2: Det(%): 88.783333 +- 0.797159 (count: 7.9600/8.9600 +- 0.6312/0.6312) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/2.7000 +- 0.0000/0.8062)
# Py.CreateData                           INFO Efficiency for L2CaloAccept_etBin2_etaBin3: Det(%): 100.000000 (114/114) | FA(%): 3.846154 (3/78)
# Py.CreateData                           INFO Train_L2CaloAccept_etBin2_etaBin3: Det(%): 100.000000 +- 0.000000 (count: 68.2800/68.2800 +- 0.8495/0.8495) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/46.8400 +- 0.0000/0.7031)
# Py.CreateData                           INFO Validation_L2CaloAccept_etBin2_etaBin3: Det(%): 100.000000 +- 0.000000 (count: 45.7200/45.7200 +- 0.8495/0.8495) | FA(%): 9.632661 +- 0.218684 (count: 3.0000/31.1600 +- 0.0000/0.7031)
# Py.CreateData                           INFO Efficiency for L2ElAccept_etBin0_etaBin0: Det(%): 0.000000 (0/122) | FA(%): 0.000000 (0/429)
# Py.CreateData                           INFO Train_L2ElAccept_etBin0_etaBin0: Det(%): 0.000000 +- 0.000000 (count: 0.0000/73.0400 +- 0.0000/0.6312) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/257.4400 +- 0.0000/0.4964)
# Py.CreateData                           INFO Validation_L2ElAccept_etBin0_etaBin0: Det(%): 0.000000 +- 0.000000 (count: 0.0000/48.9600 +- 0.0000/0.6312) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/171.5600 +- 0.0000/0.4964)
# Py.CreateData                           INFO Efficiency for L2ElAccept_etBin0_etaBin1: Det(%): 0.000000 (0/80) | FA(%): 0.000000 (0/458)
# Py.CreateData                           INFO Train_L2ElAccept_etBin0_etaBin1: Det(%): 0.000000 +- 0.000000 (count: 0.0000/48.0000 +- 0.0000/0.0000) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/274.8400 +- 0.0000/0.7031)
# Py.CreateData                           INFO Validation_L2ElAccept_etBin0_etaBin1: Det(%): 0.000000 +- 0.000000 (count: 0.0000/32.0000 +- 0.0000/0.0000) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/183.1600 +- 0.0000/0.7031)
# Py.CreateData                           INFO Efficiency for L2ElAccept_etBin0_etaBin2: Det(%): 0.000000 (0/22) | FA(%): 0.000000 (0/40)
# Py.CreateData                           INFO Train_L2ElAccept_etBin0_etaBin2: Det(%): 0.000000 +- 0.000000 (count: 0.0000/13.0400 +- 0.0000/0.6312) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/24.0000 +- 0.0000/0.0000)
# Py.CreateData                           INFO Validation_L2ElAccept_etBin0_etaBin2: Det(%): 0.000000 +- 0.000000 (count: 0.0000/8.9600 +- 0.0000/0.6312) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/16.0000 +- 0.0000/0.0000)
# Py.CreateData                           INFO Efficiency for L2ElAccept_etBin0_etaBin3: Det(%): 0.000000 (0/126) | FA(%): 0.000000 (0/345)
# Py.CreateData                           INFO Train_L2ElAccept_etBin0_etaBin3: Det(%): 0.000000 +- 0.000000 (count: 0.0000/75.6400 +- 0.0000/0.8663) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/206.9200 +- 0.0000/0.8447)
# Py.CreateData                           INFO Validation_L2ElAccept_etBin0_etaBin3: Det(%): 0.000000 +- 0.000000 (count: 0.0000/50.3600 +- 0.0000/0.8663) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/138.0800 +- 0.0000/0.8447)
# Py.CreateData                           INFO Efficiency for L2ElAccept_etBin1_etaBin0: Det(%): 0.000000 (0/488) | FA(%): 0.000000 (0/158)
# Py.CreateData                           INFO Train_L2ElAccept_etBin1_etaBin0: Det(%): 0.000000 +- 0.000000 (count: 0.0000/292.8400 +- 0.0000/0.7031) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/94.8400 +- 0.0000/0.7031)
# Py.CreateData                           INFO Validation_L2ElAccept_etBin1_etaBin0: Det(%): 0.000000 +- 0.000000 (count: 0.0000/195.1600 +- 0.0000/0.7031) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/63.1600 +- 0.0000/0.7031)
# Py.CreateData                           INFO Efficiency for L2ElAccept_etBin1_etaBin1: Det(%): 0.000000 (0/312) | FA(%): 0.000000 (0/172)
# Py.CreateData                           INFO Train_L2ElAccept_etBin1_etaBin1: Det(%): 0.000000 +- 0.000000 (count: 0.0000/187.0400 +- 0.0000/0.6312) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/103.0400 +- 0.0000/0.6312)
# Py.CreateData                           INFO Validation_L2ElAccept_etBin1_etaBin1: Det(%): 0.000000 +- 0.000000 (count: 0.0000/124.9600 +- 0.0000/0.6312) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/68.9600 +- 0.0000/0.6312)
# Py.CreateData                           INFO Efficiency for L2ElAccept_etBin1_etaBin2: Det(%): 0.000000 (0/87) | FA(%): 0.000000 (0/26)
# Py.CreateData                           INFO Train_L2ElAccept_etBin1_etaBin2: Det(%): 0.000000 +- 0.000000 (count: 0.0000/52.3000 +- 0.0000/0.8062) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/15.6400 +- 0.0000/0.8663)
# Py.CreateData                           INFO Validation_L2ElAccept_etBin1_etaBin2: Det(%): 0.000000 +- 0.000000 (count: 0.0000/34.7000 +- 0.0000/0.8062) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/10.3600 +- 0.0000/0.8663)
# Py.CreateData                           INFO Efficiency for L2ElAccept_etBin1_etaBin3: Det(%): 0.000000 (0/433) | FA(%): 0.000000 (0/151)
# Py.CreateData                           INFO Train_L2ElAccept_etBin1_etaBin3: Det(%): 0.000000 +- 0.000000 (count: 0.0000/259.5800 +- 0.0000/0.7507) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/90.5400 +- 0.0000/0.4984)
# Py.CreateData                           INFO Validation_L2ElAccept_etBin1_etaBin3: Det(%): 0.000000 +- 0.000000 (count: 0.0000/173.4200 +- 0.0000/0.7507) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/60.4600 +- 0.0000/0.4984)
# Py.CreateData                           INFO Efficiency for L2ElAccept_etBin2_etaBin0: Det(%): 0.000000 (0/127) | FA(%): 0.000000 (0/81)
# Py.CreateData                           INFO Train_L2ElAccept_etBin2_etaBin0: Det(%): 0.000000 +- 0.000000 (count: 0.0000/76.3000 +- 0.0000/0.8062) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/48.5400 +- 0.0000/0.4984)
# Py.CreateData                           INFO Validation_L2ElAccept_etBin2_etaBin0: Det(%): 0.000000 +- 0.000000 (count: 0.0000/50.7000 +- 0.0000/0.8062) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/32.4600 +- 0.0000/0.4984)
# Py.CreateData                           INFO Efficiency for L2ElAccept_etB
0.8062) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/15.6400 +- 0.0000/0.8663)
# Py.CreateData                           INFO Validation_EFElAccept_etBin1_etaBin2: Det(%): 96.727697 +- 0.922723 (count: 33.5600/34.7000 +- 0.6375/0.8062) | FA(%): 9.721212 +- 0.825089 (count: 1.0000/10.3600 +- 0.0000/0.8663)
# Py.CreateData                           INFO Efficiency for EFElAccept_etBin1_etaBin3: Det(%): 88.221709 (382/433) | FA(%): 1.986755 (3/151)
# Py.CreateData                           INFO Train_EFElAccept_etBin1_etaBin3: Det(%): 86.516568 +- 0.039027 (count: 224.5800/259.5800 +- 0.7507/0.7507) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/90.5400 +- 0.0000/0.4984)
# Py.CreateData                           INFO Validation_EFElAccept_etBin1_etaBin3: Det(%): 90.773671 +- 0.039895 (count: 157.4200/173.4200 +- 0.7507/0.7507) | FA(%): 4.962295 +- 0.040852 (count: 3.0000/60.4600 +- 0.0000/0.4984)
# Py.CreateData                           INFO Efficiency for EFElAccept_etBin2_etaBin0: Det(%): 96.850394 (123/127) | FA(%): 0.000000 (0/81)
# Py.CreateData                           INFO Train_EFElAccept_etBin2_etaBin0: Det(%): 96.067714 +- 0.041421 (count: 73.3000/76.3000 +- 0.8062/0.8062) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/48.5400 +- 0.0000/0.4984)
# Py.CreateData                           INFO Validation_EFElAccept_etBin2_etaBin0: Det(%): 98.027112 +- 0.031553 (count: 49.7000/50.7000 +- 0.8062/0.8062) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/32.4600 +- 0.0000/0.4984)
# Py.CreateData                           INFO Efficiency for EFElAccept_etBin2_etaBin1: Det(%): 94.029851 (63/67) | FA(%): 1.818182 (1/55)
# Py.CreateData                           INFO Train_EFElAccept_etBin2_etaBin1: Det(%): 92.552868 +- 0.148176 (count: 37.3000/40.3000 +- 0.8062/0.8062) | FA(%): 3.039673 +- 0.078230 (count: 1.0000/32.9200 +- 0.0000/0.8447)
# Py.CreateData                           INFO Validation_EFElAccept_etBin2_etaBin1: Det(%): 96.251225 +- 0.114557 (count: 25.7000/26.7000 +- 0.8062/0.8062) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/22.0800 +- 0.0000/0.8447)
# Py.CreateData                           INFO Efficiency for EFElAccept_etBin2_etaBin2: Det(%): 86.363636 (19/22) | FA(%): 0.000000 (0/7)
# Py.CreateData                           INFO Train_EFElAccept_etBin2_etaBin2: Det(%): 84.626374 +- 0.749270 (count: 11.0400/13.0400 +- 0.6312/0.6312) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/4.3000 +- 0.0000/0.8062)
# Py.CreateData                           INFO Validation_EFElAccept_etBin2_etaBin2: Det(%): 88.783333 +- 0.797159 (count: 7.9600/8.9600 +- 0.6312/0.6312) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/2.7000 +- 0.0000/0.8062)
# Py.CreateData                           INFO Efficiency for EFElAccept_etBin2_etaBin3: Det(%): 93.859649 (107/114) | FA(%): 0.000000 (0/78)
# Py.CreateData                           INFO Train_EFElAccept_etBin2_etaBin3: Det(%): 92.127012 +- 0.625586 (count: 62.9000/68.2800 +- 0.5000/0.8495) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/46.8400 +- 0.0000/0.7031)
# Py.CreateData                           INFO Validation_EFElAccept_etBin2_etaBin3: Det(%): 96.472514 +- 1.014161 (count: 44.1000/45.7200 +- 0.5000/0.8495) | FA(%): 0.000000 +- 0.000000 (count: 0.0000/31.1600 +- 0.0000/0.7031)

# %% [markdown]
# This time we've created the default output file (`tuningData.npz`), as can be seen with `ls` command:

# %%
# %%bash
# ls
# Out:
# CreateData.ipynb
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_nod0_L1EM18VH.npz
# tuningData.npz
# Tuning.ipynb

# %% [markdown]
# ## Example 3: Direct use of ReadData

# %% [markdown]
# Here, we run a similar example as above, but using the ReadData.

# %%
# %load ../scripts/analysis_scripts/Trigger_20_0_1_4/ReadData.py
#!/usr/bin/env python
from RingerCore.FileIO import save, load
from TuningTools.ReadData import *
import numpy as np

etaBins = [0, 0.8 , 1.37, 1.54, 2.5]
etBins  = [0,30, 50, 20000]# in GeV

#etaBins=[0.0,2.50]
#etBins=[0,200000]

output   = 'mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH'
basepath = '/afs/cern.ch/work/j/jodafons/public/Online/PhysVal'
#bkgName='user.jodafons.mc14_13TeV.129160.Pythia8_AU2CTEQ6L1_perf_JF17.recon.RDO.rel20.1.0.4.e3084_s2044_s2008_r5988.rr0040_ph0002_PhysVal.root'
#sgnName='user.jodafons.mc14_13TeV.147406.PowhegPythia8_AZNLO_Zee.recon.RDO.rel20.1.0.4.e3059_s1982_s2008_r5993_rr0040_ph0002_PhysVal.root'
bkgName='user.jodafons.mc14_13TeV.129160.Pythia8_AU2CTEQ6L1_perf_JF17.recon.RDO.rel20.1.0.4.e3084_s2044_s2008_r5988.rr0104_a0001_PhysVal.root'
sgnName='user.jodafons.mc14_13TeV.147406.PowhegPythia8_AZNLO_Zee.recon.RDO.rel20.1.0.4.e3059_s1982_s2008_r5993_rr0104_a0001_PhysVal.root'

print 'Background:'

npBkg, bkgSummary, _  = readData(basepath+'/'+bkgName, 
                         RingerOperation.L2,
                         treePath= 'Trigger/HLT/Egamma/BackgroundNtuple/e24_lhmedium_ringer_perf_L1EM20VH', 
                         #l1EmClusCut = 20, 
                         l2EtCut = 19,
                         filterType = FilterType.Background, 
                         reference = Reference.Truth,
                         etaBins=etaBins,
                         etBins=etBins,
                         nClusters=200,
                         #getRatesOnly=True,
                         )


print 'Signal:'

npSgn, sgnSummary, _  = readData(basepath+'/'+sgnName,
                         RingerOperation.L2,
                         treePath = 'Trigger/HLT/Egamma/ZeeNtuple/e24_lhmedium_ringer_perf_L1EM20VH',
                         #l1EmClusCut = 20,
                         l2EtCut = 19,
                         filterType = FilterType.Signal,
                         reference = Reference.Off_Likelihood,
                         etaBins=etaBins,
                         etBins=etBins,
                         nClusters=200,
                         #getRatesOnly=True,
                         )

summary = {'sgn':sgnSummary,'bkg':bkgSummary}
save(summary, output+'_summary')


from TuningTools.CreateData import TuningDataArchieve
import scipy.io as sio
DoMatlab=True

for cEt in range(len(etBins)-1):
  for cEta in range(len(etaBins)-1):
    sufix=('_etBin_%d_etaBin_%d')%(cEt,cEta)
    print ('Saving position: [%d][%d]')%(cEt,cEta)
    if npSgn[cEt][cEta] is None:
      npSgn[cEt][cEta] = np.array([[]])
    print 'sgn shape is ',npSgn[cEt][cEta].shape
    if npBkg[cEt][cEta] is None:
      npBkg[cEt][cEta] = np.array([[]])
    print 'bkg shape is ',npBkg[cEt][cEta].shape
    savedPath = TuningDataArchieve( output+sufix,
                                    signal_patterns = npSgn[cEt][cEta],
                                    background_patterns = npBkg[cEt][cEta] ).save()

    if DoMatlab:
      obj = {'signal_patterns':npSgn[cEt][cEta],'background_patterns':npBkg[cEt][cEta]}
      sio.savemat(output+sufix+'.mat',obj)

    print ('Saved path is %s')%(savedPath)
# Out:
# Py.ReadData                         INFO There is available a total of 15321 entries.
# Py.ReadData                         INFO L2CaloAccept_etBin0_etaB

# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin0 : 100.000000 (10/10)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin0 : 0.000000 (0/10)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin0 : 100.000000 (10/10)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin0 : 100.000000 (10/10)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin1 : 100.000000 (11/11)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin1 : 0.000000 (0/11)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin1 : 100.000000 (11/11)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin1 : 81.818182 (9/11)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin2 : 100.000000 (2/2)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin2 : 0.000000 (0/2)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin2 : 100.000000 (2/2)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin2 : 100.000000 (2/2)
# Py.ReadData                         INFO L2CaloAccept_etBin2_etaBin3 : 100.000000 (15/15)
# Py.ReadData                         INFO L2ElAccept_etBin2_etaBin3 : 0.000000 (0/15)
# Py.ReadData                         INFO EFCaloAccept_etBin2_etaBin3 : 100.000000 (15/15)
# Py.ReadData                         INFO EFElAccept_etBin2_etaBin3 : 93.333333 (14/15)
#
# Saving position: [0][0]Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
#
# sgn shape is  (10, 100)
# bkg shape is  (48, 100)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_0Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
# Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
# Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
#
# Saving position: [0][1]
# sgn shape is  (7, 100)
# bkg shape is  (28, 100)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_1
# Saving position: [0][2]
# sgn shape is  (1, 0)
# bkg shape is  (1, 100)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_2
# Saving position: [0][3]
# sgn shape is  (9, 100)
# bkg shape is  (30, 100)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_3Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
# Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
# Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
#
# Saving position: [1][0]
# sgn shape is  (53, 100)
# bkg shape is  (19, 100)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_0
# Saving position: [1][1]
# sgn shape is  (32, 100)
# bkg shape is  (17, 100)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_1
# Saving position: [1][2]
# sgn shape is  (8, 100)
# bkg shape is  (4, 100)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_2Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
# Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
# Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
#
# Saving position: [1][3]
# sgn shape is  (43, 100)
# bkg shape is  (25, 100)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_3
# Saving position: [2][0]
# sgn shape is  (10, 100)
# bkg shape is  (13, 100)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_0
# Saving position: [2][1]
# sgn shape is  (11, 100)
# bkg shape is  (7, 100)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_1Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
# Py.TuningDataArchieve                   INFO Saving data using following numpy flags: npConstants(fp_dtype=dtype('float32'),int_dtype=dtype('int32'),scounter_dtype=dtype('uint8'),flag_dtype=dtype('int8'),order=C)
#
# Saving position: [2][2]
# sgn shape is  (2, 100)
# bkg shape is  (1, 0)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_2
# Saving position: [2][3]
# sgn shape is  (15, 100)
# bkg shape is  (8, 100)
# Saved path is mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_3

# %% [markdown]
# Note that the previous script saved each of the bins in a separated file. It also exported them into matlab format:

# %%
# %%bash
# ls
# Out:
# CreateData.ipynb
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_0.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_0.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_1.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_1.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_2.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_2.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_3.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_0_etaBin_3.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_0.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_0.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_1.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_1.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_2.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_2.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_3.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_1_etaBin_3.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_0.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_0.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_1.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_1.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_2.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_2.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_3.mat
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_etBin_2_etaBin_3.npz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_L1EM20VH_summary.pic.gz
# mc14_13TeV.147406.129160.sgn.offLikelihood.bkg.truth.trig.e24_lhmedium_nod0_L1EM18VH.npz
# tuningData.npz
# Tuning.ipynb

# %% [markdown]
# <script type="text/javascript">
#     show=true;
#     function toggle(){
#         if (show){
#             $('div.input').hide();
#         }else{
#             $('div.input').show();
#         }
#         show = !show
#     }
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')
# </script>
# <a href="javascript:toggle()" target="_self"></a>
